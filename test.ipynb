# %%
import pandas as pd
import pandas_ta as ta
from flask import jsonify
data=pd.read_csv('test_data/NIFTY23DEC16500CE.csv')

# %%
data
# Out:
#      Unnamed: 0                       date     open     high     low   close  \
# 0             0  2023-02-02 09:15:00+05:30  2100.05  2100.05  2100.0  2100.0
# 1             1  2023-02-02 10:15:00+05:30  2100.00  2100.00  2100.0  2100.0
# 2             2  2023-02-02 11:15:00+05:30  2100.00  2100.00  2100.0  2100.0
# 3             3  2023-02-02 12:15:00+05:30  2100.00  2100.00  2100.0  2100.0
# 4             4  2023-02-02 13:15:00+05:30  2100.00  2100.00  2100.0  2100.0
# ..          ...                        ...      ...      ...     ...     ...
# 206         206  2023-07-20 15:15:00+05:30  3850.00  3850.00  3850.0  3850.0
# 207         207  2023-07-21 09:15:00+05:30  3850.00  3850.00  3850.0  3850.0
# 208         208  2023-07-27 14:15:00+05:30  3600.00  3600.00  3600.0  3600.0
# 209         209  2023-07-27 15:15:00+05:30  3600.00  3600.00  3600.0  3600.0
# 210         210  2023-07-28 09:15:00+05:30  3600.00  3600.00  3600.0  3600.0
#
#      volume    oi
# 0       100  2750
# ...

# %%
data=pd.read_csv('test_data/LICI_minute_data_with_indicators.csv')
data[:500][['date','open','high','low','close']].to_dict(orient='records')
# Out:
# [{'date': '2022-05-17 10:47:00+05:30',
#   'open': 899.8,
#   'high': 900.85,
#   'low': 899.5,
#   'close': 900.85},
#  {'date': '2022-05-17 10:48:00+05:30',
#   'open': 900.75,
#   'high': 900.95,
#   'low': 900.35,
#   'close': 900.8},
#  {'date': '2022-05-17 10:49:00+05:30',
#   'open': 900.9,
#   'high': 901.95,
#   'low': 900.5,
#   'close': 901.9},
#  {'date': '2022-05-17 10:50:00+05:30',
#   'open': 902.0,
#   'high': 903.0,
#   'low': 901.15,
#   'close': 902.4},
#  {'date': '2022-05-17 10:51:00+05:30',
#   'open': 902.0,
#   'high': 902.1,
#   'low': 901.25,
#   'close': 901.8},
#  {'date': '2022-05-17 10:52:00+05:30',
#   'open': 901.8,
#   'high': 901.9,
#   'low': 901.1,
#   'close': 901.45},
#  {'date': '2022-05-17 10:53:00+05:30',
#   'open': 901.2,
#   'high': 901.75,
#   'low': 900.2,
#   'close': 900.45},
#  {'date': '2022-05-17 10:54:00+05:30',
#   'open': 900.35,
#   'high': 900.35,
#   'low': 897.8,
#   'close': 898.8},
#  {'date': '2022-05-17 10:55:00+05:30',
# ...

# %%
data1.to_dict(orient='records')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\mange\Desktop\shubham_assignment\test.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> data1.to_dict(orient='records')
#
# NameError: name 'data1' is not defined

# %%
data['date'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\mange\Desktop\shubham_assignment\test.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> data['date'].astype(int)
#
# File c:\Users\mange\.conda\envs\algo\lib\site-packages\pandas\core\generic.py:5806, in NDFrame.astype(self, dtype, copy, errors)
#    5799     results = [
#    5800         self.iloc[:, i].astype(dtype, copy=copy)
#    5801         for i in range(len(self.columns))
#    5802     ]
#    5804 else:
#    5805     # else, only a single dtype is given
# -> 5806     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807     return self._constructor(new_data).__finalize__(self, method="astype")
#    5809 # GH 33113: handle empty frame or series
#
# ...

# %%
def convert_to_unix_timestamp(date_string):
    date_obj = pd.to_datetime(date_string)
    return int(date_obj.timestamp())  # Convert to milliseconds

# %%
data['date'].apply(convert_to_unix_timestamp)
# Out:
# 0      1675309500
# 1      1675313100
# 2      1675316700
# 3      1675320300
# 4      1675323900
#           ...
# 206    1689846300
# 207    1689911100
# 208    1690447500
# 209    1690451100
# 210    1690515900
# Name: date, Length: 211, dtype: int64

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()
sparkContext=spark.sparkContext
sparkContext.parallelize()
spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()
spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()

# %%
data=spark.read.csv('test_data/NIFTY23DEC16500CE.csv',inferSchema=True,header=True)

# %%
import os
os.listdir("data")
'ACC_minute_data_with_indicators.csv' in os.listdir("data")
# Out:
# True

# %%
import pyspark.sql.functions as f
data['date'] = data.select(f.date_format('date', 'yyyy:dd:MM HH:MM:SS').alias('date')).collect()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mange\Desktop\shubham_assignment\test.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> import pyspark.sql.functions as f
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> data['date'] = data.select(f.date_format('date', 'yyyy:dd:MM HH:MM:SS').alias('date')).collect()
#
# TypeError: 'DataFrame' object does not support item assignment

# %%
import pandas as pd
import datetime
data = pd.read_csv("test_data/LICI_minute_data_with_indicators.csv")
data['date'] = pd.to_datetime(data['date'])
data = data.loc[(data.date.dt.time >= datetime.time(9, 15)) & (data.date.dt.time < datetime.time(15, 30))]
data = data.set_index(pd.DatetimeIndex(data['date']))
data = data.resample('240T',offset = '75T').agg({
        'open': 'first',
        'high': 'max',
        'low': 'min',
        'close': 'last',
        'volume': 'sum'
    })

# %%
data[40:60]
# Out:
#                              open    high     low   close   volume
# date
# 2022-05-24 01:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-24 05:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-24 09:15:00+05:30  818.00  834.55  817.90  826.35  3161651
# 2022-05-24 13:15:00+05:30  826.50  828.20  820.10  824.80  1098244
# 2022-05-24 17:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-24 21:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-25 01:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-25 05:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-25 09:15:00+05:30  831.50  841.00  826.75  830.30  2639914
# 2022-05-25 13:15:00+05:30  830.00  834.90  814.25  814.95  1337742
# 2022-05-25 17:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-25 21:15:00+05:30     NaN     NaN     NaN     NaN        0
# 2022-05-26 01:15:00+05:30     NaN     NaN     NaN     NaN        0
# ...

# %%
import datetime
data['date'] = data['date'].dt.round('min')
data = data.loc[(data.date.dt.time >= datetime.time(9, 15)) & (data.date.dt.time < datetime.time(15, 30))]
data = data.set_index(pd.DatetimeIndex(data['date']))
data = data.resample('120T',offset = "75T").agg({
        'open': 'first',
        'high': 'max',
        'low': 'min',
        'close': 'last',
        'volume': 'sum'
    })

# %%
data.index.apply(
        lambda x: x.strftime("%H:%m:%S"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mange\Desktop\shubham_assignment\test.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> data.index.apply(
#       <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a>         lambda x: x.strftime("%H:%m:%S"))
#
# AttributeError: 'DatetimeIndex' object has no attribute 'apply'

# %%
data.dropna()
# Out:
#                              open    high     low   close   volume
# date
# 2022-05-17 09:15:00+05:30  899.80  903.00  877.60  881.25  5294215
# 2022-05-17 11:15:00+05:30  881.50  896.90  876.10  882.85  6186581
# 2022-05-17 13:15:00+05:30  882.85  887.90  872.55  875.50  8072808
# 2022-05-17 15:15:00+05:30  875.50  875.50  872.00  873.00  2282995
# 2022-05-18 09:15:00+05:30  885.55  890.45  877.10  882.80  5508372
# ...                           ...     ...     ...     ...      ...
# 2022-10-20 15:15:00+05:30  601.35  601.80  600.00  600.40   175346
# 2022-10-21 09:15:00+05:30  601.15  601.15  594.20  594.40   773531
# 2022-10-21 11:15:00+05:30  594.40  594.95  592.60  593.20   321226
# 2022-10-21 13:15:00+05:30  593.20  593.50  589.00  589.50   577444
# 2022-10-21 15:15:00+05:30  589.35  589.50  588.00  588.95   169787
#
# [412 rows x 5 columns]

# %%
pdf = pd.read_csv(r'data/stock_data.zip',compression='zip', sep=';')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\mange\Desktop\shubham_assignment\test.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> pdf = pd.read_csv(r'data/stock_data.zip',compression='zip', sep=';')
#
# File c:\Users\mange\.conda\envs\algo\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
import shutil
import zipfile

z = zipfile.ZipFile('data/stock_data.zip')

# %%
df=pd.DataFrame(z.filelist,columns=['zipobj'])

# %%
df['filename'] = df['zipobj'].apply(lambda x:x.filename)

# %%
df.iloc[1].values[0].filename
# Out:
# 'ACC_minute_data_with_indicators.csv'

# %%
df
# Out:
#                                                 zipobj  \
# 0    <ZipInfo filename='1. Data description.txt' co...
# 1    <ZipInfo filename='ACC_minute_data_with_indica...
# 2    <ZipInfo filename='ADANIENT_minute_data_with_i...
# 3    <ZipInfo filename='ADANIGREEN_minute_data_with...
# 4    <ZipInfo filename='ADANIPORTS_minute_data_with...
# ..                                                 ...
# 97   <ZipInfo filename='ULTRACEMCO_minute_data_with...
# 98   <ZipInfo filename='UPL_minute_data_with_indica...
# 99   <ZipInfo filename='VEDL_minute_data_with_indic...
# 100  <ZipInfo filename='WIPRO_minute_data_with_indi...
# 101  <ZipInfo filename='YESBANK_minute_data_with_in...
#
#                                        filename
# 0                       1. Data description.txt
# 1           ACC_minute_data_with_indicators.csv
# 2      ADANIENT_minute_data_with_indicators.csv
# 3    ADANIGREEN_minute_data_with_indicators.csv
# 4    ADANIPORTS_minute_data_with_indicators.csv
# ...

# %%
def extraction(filename):
    z.extract(filename,"data")

# %%
word=spark.parallelize(df['filename'].tolist())
word.foreach(extraction)
# Out:
# Traceback (most recent call last):
#   File "c:\Users\mange\.conda\envs\algo\lib\site-packages\pyspark\serializers.py", line 437, in dumps
#     return cloudpickle.dumps(obj, pickle_protocol)
#   File "c:\Users\mange\.conda\envs\algo\lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 73, in dumps
#     cp.dump(obj)
#   File "c:\Users\mange\.conda\envs\algo\lib\site-packages\pyspark\cloudpickle\cloudpickle_fast.py", line 563, in dump
#     return Pickler.dump(self, obj)
# TypeError: cannot pickle '_io.BufferedReader' object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\mange\.conda\envs\algo\lib\site-packages\pyspark\serializers.py:437, in CloudPickleSerializer.dumps(self, obj)
#     436 try:
# --> 437     return cloudpickle.dumps(obj, pickle_protocol)
#     438 except pickle.PickleError:
#
# ...

# %%
z.read("ACC_minute_data_with_indicators.csv")

# %%
data= pd.read_csv('c:\\Users\\mange\\Desktop\\shubham_assignment\\ACC_minute_data_with_indicators.csv')[0:5000][['date','open','high','low','close']]

# %%
data_sp = spark.read.csv('c:\\Users\\mange\\Desktop\\shubham_assignment\\ACC_minute_data_with_indicators.csv',header=True,inferSchema=True)

# %%
data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
data_pd['date1'] = pd.to_datetime(data_pd['date'])
data_pd = data_pd.set_index(pd.DatetimeIndex(data_pd['date1']))
data_pd[['date','open','high','low','close']][:20].to_dict(orient='records')
# Out:
# [{'date': '2015-02-02 10:18:00+05:30',
#   'open': 1545.0,
#   'high': 1545.0,
#   'low': 1543.1,
#   'close': 1544.0},
#  {'date': '2015-02-02 10:19:00+05:30',
#   'open': 1544.0,
#   'high': 1544.0,
#   'low': 1543.0,
#   'close': 1543.7},
#  {'date': '2015-02-02 10:20:00+05:30',
#   'open': 1543.7,
#   'high': 1543.7,
#   'low': 1542.5,
#   'close': 1543.0},
#  {'date': '2015-02-02 10:21:00+05:30',
#   'open': 1543.0,
#   'high': 1543.0,
#   'low': 1542.3,
#   'close': 1542.3},
#  {'date': '2015-02-02 10:22:00+05:30',
#   'open': 1541.1,
#   'high': 1542.15,
#   'low': 1541.1,
#   'close': 1542.1},
#  {'date': '2015-02-02 10:23:00+05:30',
#   'open': 1542.1,
#   'high': 1542.1,
#   'low': 1541.0,
#   'close': 1541.0},
#  {'date': '2015-02-02 10:24:00+05:30',
#   'open': 1541.0,
#   'high': 1541.0,
#   'low': 1540.35,
#   'close': 1540.35},
#  {'date': '2015-02-02 10:25:00+05:30',
#   'open': 1540.35,
#   'high': 1543.15,
#   'low': 1540.35,
#   'close': 1543.15},
# ...

# %%
data = data_pd[['date','open','high','low','close','volume']]
data['date'] = pd.to_datetime(data['date'])
data = data.set_index(pd.DatetimeIndex(data['date']))
data = data.resample('120T',offset = "75T").agg({
        'open': 'first',
        'high': 'max',
        'low': 'min',
        'close': 'last',
        'volume': 'sum'
    })
# Out:
# c:\Users\mange\.conda\envs\algo\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
data1 = data.dropna()

# %%
def get_data(stock_name):
    if stock_name+"_minute_data_with_indicators.csv" in os.listdir("data"):
        return pd.read_csv(stock_name+"_minute_data_with_indicators.csv",index_col=False)[['date','open','high','low','close']]

# %%
data =get_data("ACC")

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Sep  9 22:06:06 2023

@author: Trader_MIKE
"""

import pandas as pd
import pandas_ta as ta

data = {'Date': pd.date_range(start='2023-01-01', periods=100, freq='D'),
            'Open': [100.0] * 100,
            'High': [110.0] * 100,
            'Low': [90.0] * 100,
            'Close': [105.0] * 100}
    
df = pd.DataFrame(data)



# Display the DataFrame with calculated indicators
print(df_with_indicators)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mange\Desktop\shubham_assignment\test.ipynb Cell 34 in <cell line: 55>()
#      <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X44sZmlsZQ%3D%3D?line=62'>63</a> df = pd.DataFrame(data)
#      <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X44sZmlsZQ%3D%3D?line=64'>65</a> # Calculate indicators with default parameters
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X44sZmlsZQ%3D%3D?line=65'>66</a> df_with_indicators = calculate_technical_indicators(df)
#      <a href='vscode-notebook-cell:/c%3A/Users/mange/Desktop/shubham_assignment/test.ipynb#X44sZmlsZQ%3D%3D?line=67'>68</a> # Display the DataFrame with calculated indicators
# ...

# %%
def get_data_raw(stock_name,time_interval):
    z = zipfile.ZipFile('data/stock_data.zip')
    df=pd.DataFrame(z.filelist,columns=['zipobj'])
    df['filename'] = df['zipobj'].apply(lambda x:x.filename)
    if stock_name+"_minute_data_with_indicators.csv" in os.listdir("data"):
        data = pd.read_csv("data/"+stock_name+"_minute_data_with_indicators.csv",index_col=False)[['date','open','high','low','close','volume']][0:1000]
        data['date1'] = pd.to_datetime(data['date'])
        data = data.loc[(data.date1.dt.time >= datetime.time(9, 15)) & (data.date1.dt.time < datetime.time(15, 30))]
        data = data.set_index(pd.DatetimeIndex(data['date1']))
        if time_interval == '5min':
            return data.resample('5T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        elif time_interval == '30min':
            return data.resample('30T',offset = '15T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        elif time_interval == '60min':
            return data.resample('60T',offset = '15T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        elif time_interval == '240min':
            return data.resample('240T',offset = '75T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna() 
        elif time_interval == '120min':
            return data.resample('120T',offset = "75T").agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        else:
            return data
    else:
        data = pd.read_csv(z.extract(stock_name+"_minute_data_with_indicators.csv","data"))
        data['date1'] = pd.to_datetime(data['date'])
        data = data.loc[(data.date1.dt.time >= datetime.time(9, 15)) & (data.date1.dt.time < datetime.time(15, 30))]
        data = data.set_index(pd.DatetimeIndex(data['date1']))
        if time_interval == '5min':
            return data.resample('5T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        elif time_interval == '30min':
            return data.resample('30T',offset = '15T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        elif time_interval == '60min':
            return data.resample('60T',offset = '15T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        elif time_interval == '240min':
            return data.resample('240T',offset = '75T').agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna() 
        elif time_interval == '120min':
            return data.resample('120T',offset = "75T").agg({
                'date':'first',
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum'
            }).dropna()
        else:
            return data
def get_data(stock_name,time_interval):
    data = get_data_raw(stock_name,time_interval)
    data_raw = data
    data = data[:200]
    data = data.join(ta.adx(data['high'],data['low'],data['close']))
    data = data.join(ta.ao(data['high'],data['low']))
    data = data.join(ta.aroon(data['high'],data['low']))
    data = data.join(ta.atr(data['high'],data['low'],data['close']))
    data = data.join(ta.cci(data['high'],data['low'],data['close']))
    data = data.join(ta.chop(data['high'],data['low'],data['close']))
    data = data.join(ta.ema(data['close']))
    data = data.join(ta.hma(data['close']))
    data = data.join(ta.macd(data['close']))
    data = data.join(ta.mom(data['close']))
    data = data.join(ta.rsi(data['close']))
    data = data.join(ta.sma(data['close']))
    data = data.join(ta.uo(data['high'],data['low'],data['close']))
    data = data.join(ta.willr(data['high'],data['low'],data['close']))
    ichimoku_data = pd.DataFrame(ta.ichimoku(data['high'],data['low'],data['close']))
    ichimoku_data
    data = data.join(ichimoku_data)
    return data_raw,data

# %%
data,data2 = get_data("ACC",'30min')

# %%
data2.iloc[-1].to_dict()
# Out:
# {'date': '2015-02-04 14:15:00+05:30',
#  'open': 1510.05,
#  'high': 1512.05,
#  'low': 1509.2,
#  'close': 1512.05,
#  'volume': 7515,
#  'ADX_14': 6.410978430531643,
#  'DMP_14': 16.148545805797124,
#  'DMN_14': 17.374073749094915,
#  'AO_5_34': -16.34308823529409,
#  'AROOND_14': 42.85714285714286,
#  'AROONU_14': 7.142857142857143,
#  'AROONOSC_14': -35.714285714285715,
#  'ATRr_14': 13.101182535817587,
#  'CCI_14_0.015': -13.758189398448991,
#  'CHOP_14_1_100': 39.41444420806942,
#  'EMA_10': 1511.4749247833001,
#  'HMA_10': 1509.0886868686805,
#  'MACD_12_26_9': -6.537060162259422,
#  'MACDh_12_26_9': -0.3613910448359494,
#  'MACDs_12_26_9': -6.175669117423473,
#  'MOM_10': -7.5,
#  'RSI_14': 44.74962528030758,
#  'SMA_10': 1509.0900000000001,
#  'UO_7_14_28': 53.95960794488804,
#  'WILLR_14': -81.28078817733994,
#  0: None}

# %%
data2
# Out:
#                                                 date     open     high  \
# date1
# 2015-02-02 10:15:00+05:30  2015-02-02 10:18:00+05:30  1545.00  1545.00
# 2015-02-02 10:45:00+05:30  2015-02-02 10:45:00+05:30  1542.00  1544.70
# 2015-02-02 11:15:00+05:30  2015-02-02 11:15:00+05:30  1540.30  1544.30
# 2015-02-02 11:45:00+05:30  2015-02-02 11:45:00+05:30  1541.00  1541.15
# 2015-02-02 12:15:00+05:30  2015-02-02 12:15:00+05:30  1527.00  1536.05
# 2015-02-02 12:45:00+05:30  2015-02-02 12:45:00+05:30  1531.80  1535.45
# 2015-02-02 13:15:00+05:30  2015-02-02 13:15:00+05:30  1535.00  1551.75
# 2015-02-02 13:45:00+05:30  2015-02-02 13:45:00+05:30  1541.10  1552.00
# 2015-02-02 14:15:00+05:30  2015-02-02 14:15:00+05:30  1551.80  1553.40
# 2015-02-02 14:45:00+05:30  2015-02-02 14:45:00+05:30  1520.65  1531.00
# 2015-02-02 15:15:00+05:30  2015-02-02 15:15:00+05:30  1528.70  1529.90
# 2015-02-03 09:15:00+05:30  2015-02-03 09:15:00+05:30  1515.00  1537.65
# ...

# %%
datetime.datetime.strptime("2023-09-10","%Y-%M-%d")
# Out:
# datetime.datetime(2023, 1, 10, 0, 9)

# %%
stock_name = "ACC"
data = pd.read_csv("data/"+stock_name+"_minute_data_with_indicators.csv",index_col=False)[['date','open','high','low','close','volume']]
data['date1'] = pd.to_datetime(data['date'])

# %%
data.head()
# Out:
#                         date    open     high     low   close  volume  \
# 0  2015-02-02 10:18:00+05:30  1545.0  1545.00  1543.1  1544.0     220
# 1  2015-02-02 10:19:00+05:30  1544.0  1544.00  1543.0  1543.7      29
# 2  2015-02-02 10:20:00+05:30  1543.7  1543.70  1542.5  1543.0      28
# 3  2015-02-02 10:21:00+05:30  1543.0  1543.00  1542.3  1542.3     125
# 4  2015-02-02 10:22:00+05:30  1541.1  1542.15  1541.1  1542.1     113
#
#                       date1
# 0 2015-02-02 10:18:00+05:30
# 1 2015-02-02 10:19:00+05:30
# 2 2015-02-02 10:20:00+05:30
# 3 2015-02-02 10:21:00+05:30
# 4 2015-02-02 10:22:00+05:30

# %%
from_time = "2015-04-10"
to_time = "2022-01-10"
data.loc[(data.date1.dt.time >= datetime.time(9, 15)) & 
                        (data.date1.dt.time < datetime.time(15, 30)) & (data.date1.dt.date > datetime.datetime.strptime(from_time+" 00:00:00+05:30",'%Y-%m-%d %H:%M:%S%z').date())
                        & (data.date1.dt.date < datetime.datetime.strptime(to_time+" 00:00:00+05:30","%Y-%m-%d %H:%M:%S%z").date())]
# Out:
#                              date     open     high      low    close  volume  \
# 16400   2015-04-13 09:15:00+05:30  1636.00  1636.00  1631.00  1632.00    2415
# 16401   2015-04-13 09:16:00+05:30  1632.90  1636.00  1631.00  1636.00    3468
# 16402   2015-04-13 09:17:00+05:30  1639.10  1639.10  1635.40  1635.60     699
# 16403   2015-04-13 09:18:00+05:30  1636.20  1639.20  1635.00  1637.25    1167
# 16404   2015-04-13 09:19:00+05:30  1638.65  1639.00  1635.30  1638.50    3045
# ...                           ...      ...      ...      ...      ...     ...
# 592229  2022-01-07 15:25:00+05:30  2290.05  2290.05  2288.00  2288.75    1998
# 592230  2022-01-07 15:26:00+05:30  2288.80  2290.00  2287.90  2288.30    1849
# 592231  2022-01-07 15:27:00+05:30  2289.80  2290.00  2285.90  2287.00    2572
# 592232  2022-01-07 15:28:00+05:30  2287.00  2290.00  2285.65  2290.00    2697
# 592233  2022-01-07 15:29:00+05:30  2286.05  2290.00  2285.70  2290.00     660
#
#                            date1
# ...

# %%
datetime.datetime.strptime(to_time+" 00:00:00+05:30","%Y-%m-%d %H:%M:%S%z").date()
# Out:
# datetime.date(2023, 9, 10)

# %%
data
# Out:
#                              date     open     high      low    close  volume  \
# 0       2015-02-02 10:18:00+05:30  1545.00  1545.00  1543.10  1544.00     220
# 1       2015-02-02 10:19:00+05:30  1544.00  1544.00  1543.00  1543.70      29
# 2       2015-02-02 10:20:00+05:30  1543.70  1543.70  1542.50  1543.00      28
# 3       2015-02-02 10:21:00+05:30  1543.00  1543.00  1542.30  1542.30     125
# 4       2015-02-02 10:22:00+05:30  1541.10  1542.15  1541.10  1542.10     113
# ...                           ...      ...      ...      ...      ...     ...
# 660528  2022-10-24 19:10:00+05:30  2255.80  2255.90  2254.55  2255.00     199
# 660529  2022-10-24 19:11:00+05:30  2255.75  2255.95  2254.55  2255.95     227
# 660530  2022-10-24 19:12:00+05:30  2256.00  2256.25  2255.35  2256.25     594
# 660531  2022-10-24 19:13:00+05:30  2255.50  2255.95  2254.55  2255.00     267
# 660532  2022-10-24 19:14:00+05:30  2255.00  2259.00  2254.00  2256.00     365
#
#                            date1
# ...
